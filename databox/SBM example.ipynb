# %%
import matplotlib.pyplot as plt

# %%
# Out:
# 2

# %%
# Out:
#   File "/tmp/ipykernel_10/3044493062.py", line 1
#     import graph-tool as gt
#                 ^
# SyntaxError: invalid syntax

# %%
from graph_tool.all import *

# %%
g = collection.data["football"]
print(g)
# Out:
# <Graph object, undirected, with 115 vertices and 613 edges, 4 internal vertex properties, 2 internal graph properties, at 0x7f6aae145ff0>

# %%
state = minimize_blockmodel_dl(g)

# %%
state.draw(pos=g.vp.pos)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f6aae145ff0, at 0x7f6af03bc760>

# %%
b = contiguous_map(state.get_blocks())
state = state.copy(b=b)

e = state.get_matrix()

B = state.get_nonempty_B()
plt.matshow(e.todense()[:B, :B])
